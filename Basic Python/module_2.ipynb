# %%
print("Hello World")
# Out:
# Hello World

# %%
first_val = "hello"

num = 123

overall = first_val + " " + num +" " + "hello"

print(overall)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 first_val = "hello"
#       3 num = 123
# ----> 5 overall = first_val + " " + num +" " + "hello"
#       7 print(overall)
#
# TypeError: can only concatenate str (not "int") to str

# %%
fst = "hello"
secnd = "im naim, im from bangladesh"
print(fst+" "+secnd)
# Out:
# hello im naim, im from bangladesh
