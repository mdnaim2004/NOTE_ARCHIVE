# %%
print("Hello World")
# Out:
# Hello World

# %%
# first_val = "hello"

# num = 123

# overall = first_val + " " + num +" " + "hello"

# print(overall)

# %%
fst = "hello"
secnd = "im naim, im from bangladesh"
print(fst+" "+secnd)
# Out:
# hello im naim, im from bangladesh

# %% [markdown]
# ### String Methode

# %%
l = "  this is a text  "

print(l.upper())
print(l.strip())
print(l.title())

print(l.strip().title())
# Out:
#   THIS IS A TEXT
# this is a text
#   This Is A Text
# This Is A Text
