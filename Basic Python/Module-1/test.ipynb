# %% [markdown]
# ### 🔹 My Skills
#
# <table align="center">
#   <tr>
#     <td align="center" width="150">
#       <a href="https://www.cprogramming.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=c" width="60" height="60" alt="C" />
#       </a>
#       <br><strong>C</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://isocpp.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=cpp" width="60" height="60" alt="C++" />
#       </a>
#       <br><strong>C++</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://www.java.com" target="_blank">
#         <img src="https://skillicons.dev/icons?i=java" width="60" height="60" alt="Java" />
#       </a>
#       <br><strong>Java</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://www.python.org" target="_blank">
#         <img src="https://skillicons.dev/icons?i=python" width="60" height="60" alt="Python" />
#       </a>
#       <br><strong>Python</strong>
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="150">
#       <a href="https://developer.mozilla.org/en-US/docs/Web/JavaScript" target="_blank">
#         <img src="https://skillicons.dev/icons?i=js" width="60" height="60" alt="JavaScript" />
#       </a>
#       <br><strong>JavaScript</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://numpy.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=numpy" width="60" height="60" alt="NumPy" />
#       </a>
#       <br><strong>NumPy</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://pandas.pydata.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=pandas" width="60" height="60" alt="Pandas" />
#       </a>
#       <br><strong>Pandas</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://scikit-learn.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=sklearn" width="60" height="60" alt="scikit-learn" />
#       </a>
#       <br><strong>scikit-learn</strong>
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="150">
#       <a href="https://www.tensorflow.org" target="_blank">
#         <img src="https://skillicons.dev/icons?i=tensorflow" width="60" height="60" alt="TensorFlow" />
#       </a>
#       <br><strong>TensorFlow</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://pytorch.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=pytorch" width="60" height="60" alt="PyTorch" />
#       </a>
#       <br><strong>PyTorch</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://opencv.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=opencv" width="60" height="60" alt="OpenCV" />
#       </a>
#       <br><strong>OpenCV</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://keras.io/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=keras" width="60" height="60" alt="Keras" />
#       </a>
#       <br><strong>Keras</strong>
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="150">
#       <a href="https://matplotlib.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=matplotlib" width="60" height="60" alt="Matplotlib" />
#       </a>
#       <br><strong>Matplotlib</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://scipy.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=scipy" width="60" height="60" alt="SciPy" />
#       </a>
#       <br><strong>SciPy</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://git-scm.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=git" width="60" height="60" alt="Git" />
#       </a>
#       <br><strong>Git</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://github.com" target="_blank">
#         <img src="https://skillicons.dev/icons?i=github" width="60" height="60" alt="GitHub" />
#       </a>
#       <br><strong>GitHub</strong>
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="150">
#       <a href="https://code.visualstudio.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=vscode" width="60" height="60" alt="VS Code" />
#       </a>
#       <br><strong>VS Code</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://learn.microsoft.com/en-us/powershell/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=powershell" width="60" height="60" alt="PowerShell" />
#       </a>
#       <br><strong>PowerShell</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://www.microsoft.com/en-us/windows" target="_blank">
#         <img src="https://skillicons.dev/icons?i=windows" width="60" height="60" alt="Windows" />
#       </a>
#       <br><strong>Windows</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://app.diagrams.net/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=diagrams" width="60" height="60" alt="draw.io" />
#       </a>
#       <br><strong>draw.io</strong>
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="150">
#       <a href="https://www.latex-project.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=latex" width="60" height="60" alt="LaTeX" />
#       </a>
#       <br><strong>LaTeX</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://chat.openai.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=openai" width="60" height="60" alt="ChatGPT" />
#       </a>
#       <br><strong>ChatGPT</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://gemini.google.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=gemini" width="60" height="60" alt="Gemini" />
#       </a>
#       <br><strong>Gemini</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://x.ai/grok" target="_blank">
#         <img src="https://skillicons.dev/icons?i=grok" width="60" height="60" alt="Grok" />
#       </a>
#       <br><strong>Grok</strong>
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="150">
#       <a href="https://www.figma.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=figma" width="60" height="60" alt="Figma" />
#       </a>
#       <br><strong>Figma</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://www.canva.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=canva" width="60" height="60" alt="Canva" />
#       </a>
#       <br><strong>Canva</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://obsproject.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=obs" width="60" height="60" alt="OBS Studio" />
#       </a>
#       <br><strong>OBS Studio</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://www.capcut.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=capcut" width="60" height="60" alt="CapCut" />
#       </a>
#       <br><strong>CapCut</strong>
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="150">
#       <a href="https://anydesk.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=anydesk" width="60" height="60" alt="AnyDesk" />
#       </a>
#       <br><strong>AnyDesk</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://discord.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=discord" width="60" height="60" alt="Discord" />
#       </a>
#       <br><strong>Discord</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://www.microsoft.com/en-us/edge" target="_blank">
#         <img src="https://skillicons.dev/icons?i=edge" width="60" height="60" alt="Microsoft Edge" />
#       </a>
#       <br><strong>Microsoft Edge</strong>
#     </td>
#     <td align="center" width="150">
#       <a href="https://www.google.com/chrome" target="_blank">
#         <img src="https://skillicons.dev/icons?i=chrome" width="60" height="60" alt="Chrome" />
#       </a>
#       <br><strong>Chrome</strong>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### 💻 My Technology Stack
#
# <table align="center">
#   <tr>
#     <td align="center" width="96">
#       <a href="https://www.cprogramming.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=c" width="40" height="40" alt="C" />
#       </a>
#       <br>C
#     </td>
#     <td align="center" width="96">
#       <a href="https://isocpp.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=cpp" width="40" height="40" alt="C++" />
#       </a>
#       <br>C++
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.java.com" target="_blank">
#         <img src="https://skillicons.dev/icons?i=java" width="40" height="40" alt="Java" />
#       </a>
#       <br>Java
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.python.org" target="_blank">
#         <img src="https://skillicons.dev/icons?i=python" width="40" height="40" alt="Python" />
#       </a>
#       <br>Python
#     </td>
#     <td align="center" width="96">
#       <a href="https://developer.mozilla.org/en-US/docs/Web/JavaScript" target="_blank">
#         <img src="https://skillicons.dev/icons?i=js" width="40" height="40" alt="JavaScript" />
#       </a>
#       <br>JavaScript
#     </td>
#     <td align="center" width="96">
#       <a href="https://git-scm.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=git" width="40" height="40" alt="Git" />
#       </a>
#       <br>Git
#     </td>
#     <td align="center" width="96">
#       <a href="https://github.com" target="_blank">
#         <img src="https://skillicons.dev/icons?i=github" width="40" height="40" alt="GitHub" />
#       </a>
#       <br>GitHub
#     </td>
#     <td align="center" width="96">
#       <a href="https://code.visualstudio.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=vscode" width="40" height="40" alt="VS Code" />
#       </a>
#       <br>VS Code
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="96">
#       <a href="https://numpy.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=numpy" width="40" height="40" alt="NumPy" />
#       </a>
#       <br>NumPy
#     </td>
#     <td align="center" width="96">
#       <a href="https://pandas.pydata.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=pandas" width="40" height="40" alt="Pandas" />
#       </a>
#       <br>Pandas
#     </td>
#     <td align="center" width="96">
#       <a href="https://scikit-learn.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=sklearn" width="40" height="40" alt="scikit-learn" />
#       </a>
#       <br>scikit-learn
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.tensorflow.org" target="_blank">
#         <img src="https://skillicons.dev/icons?i=tensorflow" width="40" height="40" alt="TensorFlow" />
#       </a>
#       <br>TensorFlow
#     </td>
#     <td align="center" width="96">
#       <a href="https://pytorch.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=pytorch" width="40" height="40" alt="PyTorch" />
#       </a>
#       <br>PyTorch
#     </td>
#     <td align="center" width="96">
#       <a href="https://opencv.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=opencv" width="40" height="40" alt="OpenCV" />
#       </a>
#       <br>OpenCV
#     </td>
#     <td align="center" width="96">
#       <a href="https://keras.io/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=keras" width="40" height="40" alt="Keras" />
#       </a>
#       <br>Keras
#     </td>
#     <td align="center" width="96">
#       <a href="https://matplotlib.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=matplotlib" width="40" height="40" alt="Matplotlib" />
#       </a>
#       <br>Matplotlib
#     </td>
#   </tr>
#   <tr>
#     <td align="center" width="96">
#       <a href="https://scipy.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=scipy" width="40" height="40" alt="SciPy" />
#       </a>
#       <br>SciPy
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.latex-project.org/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=latex" width="40" height="40" alt="LaTeX" />
#       </a>
#       <br>LaTeX
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.figma.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=figma" width="40" height="40" alt="Figma" />
#       </a>
#       <br>Figma
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.canva.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=canva" width="40" height="40" alt="Canva" />
#       </a>
#       <br>Canva
#     </td>
#     <td align="center" width="96">
#       <a href="https://obsproject.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=obs" width="40" height="40" alt="OBS Studio" />
#       </a>
#       <br>OBS Studio
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.capcut.com/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=capcut" width="40" height="40" alt="CapCut" />
#       </a>
#       <br>CapCut
#     </td>
#     <td align="center" width="96">
#       <a href="https://www.microsoft.com/en-us/windows" target="_blank">
#         <img src="https://skillicons.dev/icons?i=windows" width="40" height="40" alt="Windows" />
#       </a>
#       <br>Windows
#     </td>
#     <td align="center" width="96">
#       <a href="https://learn.microsoft.com/en-us/powershell/" target="_blank">
#         <img src="https://skillicons.dev/icons?i=powershell" width="40" height="40" alt="PowerShell" />
#       </a>
#       <br>PowerShell
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <table align="center">
#
# <!-- Programming -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=c" width="60"/><br><b>C</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=cpp" width="60"/><br><b>C++</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=java" width="60"/><br><b>Java</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=python" width="60"/><br><b>Python</b>
# </td>
# </tr>
#
# <!-- ML -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=js" width="60"/><br><b>JavaScript</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=numpy" width="60"/><br><b>NumPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=pandas" width="60"/><br><b>Pandas</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=sklearn" width="60"/><br><b>scikit-learn</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=tensorflow" width="60"/><br><b>TensorFlow</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=pytorch" width="60"/><br><b>PyTorch</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=opencv" width="60"/><br><b>OpenCV</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=keras" width="60"/><br><b>Keras</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=matplotlib" width="60"/><br><b>Matplotlib</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=scipy" width="60"/><br><b>SciPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=git" width="60"/><br><b>Git</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=github" width="60"/><br><b>GitHub</b>
# </td>
# </tr>
#
# <!-- Tools -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=vscode" width="60"/><br><b>VS Code</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/af/PowerShell_Core_6.0_icon.png" width="60"/><br><b>PowerShell</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=windows" width="60"/><br><b>Windows</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/diagramsdotnet/diagrams.net/main/webapp/images/favicon-192.png" width="60"/><br><b>draw.io</b>
# </td>
# </tr>
#
# <!-- Docs & AI -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=latex" width="60"/><br><b>LaTeX</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/openai.svg" width="60"/><br><b>ChatGPT</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/google.svg" width="60"/><br><b>Gemini</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/x.svg" width="60"/><br><b>Grok</b>
# </td>
# </tr>
#
# <!-- Design & Media -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=figma" width="60"/><br><b>Figma</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=canva" width="60"/><br><b>Canva</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/75/OBS_Studio_Logo.png" width="60"/><br><b>OBS Studio</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/3e/CapCut_logo.png" width="60"/><br><b>CapCut</b>
# </td>
# </tr>
#
# <!-- Communication -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=anydesk" width="60"/><br><b>AnyDesk</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=discord" width="60"/><br><b>Discord</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=edge" width="60"/><br><b>Edge</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=chrome" width="60"/><br><b>Chrome</b>
# </td>
# </tr>
#
# </table>

# %% [markdown]
# <style>
#   .dark-only { display: none; }
#   .light-only { display: inline; }
#
#   @media (prefers-color-scheme: dark) {
#     .dark-only { display: inline; }
#     .light-only { display: none; }
#   }
# </style>
#
# <h3 align="center">🔹 My Skills</h3>
#
# <table align="center">
#
# <tr>
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=python&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=python&theme=dark" width="60"/>
#   <br><b>Python</b>
# </td>
#
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=cpp&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=cpp&theme=dark" width="60"/>
#   <br><b>C++</b>
# </td>
#
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=java&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=java&theme=dark" width="60"/>
#   <br><b>Java</b>
# </td>
#
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=js&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=js&theme=dark" width="60"/>
#   <br><b>JavaScript</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=pytorch&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=pytorch&theme=dark" width="60"/>
#   <br><b>PyTorch</b>
# </td>
#
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=tensorflow&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=tensorflow&theme=dark" width="60"/>
#   <br><b>TensorFlow</b>
# </td>
#
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=opencv&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=opencv&theme=dark" width="60"/>
#   <br><b>OpenCV</b>
# </td>
#
# <td align="center" width="150">
#   <img class="light-only" src="https://skillicons.dev/icons?i=git&theme=light" width="60"/>
#   <img class="dark-only"  src="https://skillicons.dev/icons?i=git&theme=dark" width="60"/>
#   <br><b>Git</b>
# </td>
# </tr>
#
# </table>

# %% [markdown]
# <table align="center">
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=c" width="60"/><br><b>C</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=cpp" width="60"/><br><b>C++</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=java" width="60"/><br><b>Java</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=python" width="60"/><br><b>Python</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=js" width="60"/><br><b>JavaScript</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=numpy" width="60"/><br><b>NumPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=pandas" width="60"/><br><b>Pandas</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=sklearn" width="60"/><br><b>scikit-learn</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=tensorflow" width="60"/><br><b>TensorFlow</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=pytorch" width="60"/><br><b>PyTorch</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=opencv" width="60"/><br><b>OpenCV</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=keras" width="60"/><br><b>Keras</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=matplotlib" width="60"/><br><b>Matplotlib</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=scipy" width="60"/><br><b>SciPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=git" width="60"/><br><b>Git</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=github" width="60"/><br><b>GitHub</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=vscode" width="60"/><br><b>VS Code</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=powershell" width="60"/><br><b>PowerShell</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=windows" width="60"/><br><b>Windows</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=drawio" width="60"/><br><b>draw.io</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=latex" width="60"/><br><b>LaTeX</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=openai" width="60"/><br><b>ChatGPT</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=gemini" width="60"/><br><b>Gemini</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=grok" width="60"/><br><b>Grok</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=figma" width="60"/><br><b>Figma</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=canva" width="60"/><br><b>Canva</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=obs" width="60"/><br><b>OBS Studio</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=capcut" width="60"/><br><b>CapCut</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=anydesk" width="60"/><br><b>AnyDesk</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=discord" width="60"/><br><b>Discord</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=edge" width="60"/><br><b>Edge</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=chrome" width="60"/><br><b>Chrome</b>
# </td>
# </tr>
#
# </table>

# %% [markdown]
# <table align="center">
# <!-- Programming -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=c" width="60"/><br><b>C</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=cpp" width="60"/><br><b>C++</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=java" width="60"/><br><b>Java</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=python" width="60"/><br><b>Python</b>
# </td>
# </tr>
# <!-- ML -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=js" width="60"/><br><b>JavaScript</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/numpy/numpy-original.svg" width="60"/><br><b>NumPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/pandas/pandas-original.svg" width="60"/><br><b>Pandas</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=sklearn" width="60"/><br><b>scikit-learn</b>
# </td>
# </tr>
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=tensorflow" width="60"/><br><b>TensorFlow</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=pytorch" width="60"/><br><b>PyTorch</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=opencv" width="60"/><br><b>OpenCV</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=keras" width="60"/><br><b>Keras</b>
# </td>
# </tr>
# <tr>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/ed/Pandas_logo.svg" width="60"/><br><b>Matplotlib</b> <!-- Wait, wrong; corrected below -->
# Wait, Matplotlib logo: https://matplotlib.org/stable/_images/sphx_glr_logos2_001.png but better:
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/matplotlib/matplotlib-original.svg" width="60"/><br><b>Matplotlib</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/31/NumPy_logo_2020.svg" width="60"/> No, SciPy: https://raw.githubusercontent.com/devicons/devicon/master/icons/scipy/scipy-original.svg but actually no official in devicon, use:
# <img src="https://www.scipy.org/_static/logo.png" width="60"/><br><b>SciPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=git" width="60"/><br><b>Git</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=github" width="60"/><br><b>GitHub</b>
# </td>
# </tr>
# <!-- Tools -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=vscode" width="60"/><br><b>VS Code</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/af/PowerShell_Core_6.0_icon.png" width="60"/><br><b>PowerShell</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=windows" width="60"/><br><b>Windows</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/diagramsdotnet/diagrams.net/main/webapp/images/favicon-192.png" width="60"/><br><b>draw.io</b>
# </td>
# </tr>
# <!-- Docs & AI -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=latex" width="60"/><br><b>LaTeX</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/openai.svg" width="60"/><br><b>ChatGPT</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/google.svg" width="60"/><br><b>Gemini</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/x.svg" width="60"/><br><b>Grok</b>
# </td>
# </tr>
# <!-- Design & Media -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=figma" width="60"/><br><b>Figma</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/9/91/Canva_Logo_2021.svg" width="60"/><br><b>Canva</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/75/OBS_Studio_Logo.png" width="60"/><br><b>OBS Studio</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/3e/CapCut_logo.png" width="60"/><br><b>CapCut</b>
# </td>
# </tr>
# <!-- Communication -->
# <tr>
# <td align="center" width="150">
# <img src="https://www.anydesk.com/fileadmin/templates/v9/img/favicons/anydesk-icon.svg" width="60"/><br><b>AnyDesk</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=discord" width="60"/><br><b>Discord</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f7/Microsoft_Edge_logo_%282019%29.svg" width="60"/><br><b>Edge</b>
# </td>
# <td align="center" width="150">
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/e1/Google_Chrome_icon_%28February_2022%29.svg" width="60"/><br><b>Chrome</b>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table align="center">
#
# <!-- Programming -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=c" width="60"/><br><b>C</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=cpp" width="60"/><br><b>C++</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=java" width="60"/><br><b>Java</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=python" width="60"/><br><b>Python</b>
# </td>
# </tr>
#
# <!-- ML / Data -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=js" width="60"/><br><b>JavaScript</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/numpy.svg" width="60"/><br><b>NumPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/pandas.svg" width="60"/><br><b>Pandas</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/scikitlearn.svg" width="60"/><br><b>scikit-learn</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=tensorflow" width="60"/><br><b>TensorFlow</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=pytorch" width="60"/><br><b>PyTorch</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/opencv.svg" width="60"/><br><b>OpenCV</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=keras" width="60"/><br><b>Keras</b>
# </td>
# </tr>
#
# <tr>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/matplotlib.svg" width="60"/><br><b>Matplotlib</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/scipy.svg" width="60"/><br><b>SciPy</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=git" width="60"/><br><b>Git</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=github" width="60"/><br><b>GitHub</b>
# </td>
# </tr>
#
# <!-- Tools -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=vscode" width="60"/><br><b>VS Code</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/powershell.svg" width="60"/><br><b>PowerShell</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=windows" width="60"/><br><b>Windows</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/diagramsdotnet.svg" width="60"/><br><b>draw.io</b>
# </td>
# </tr>
#
# <!-- Docs & AI -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=latex" width="60"/><br><b>LaTeX</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/openai.svg" width="60"/><br><b>ChatGPT</b>
# </td>
# <td align="center" width="150">
# <img src="https://www.bing.com/images/search?view=detailV2&ccid=umfUzNjK&id=74D37301C0241B6FAA909D85F8C88FA82BFA269C&thid=OIP.umfUzNjKLT1bMF25L3QPoAHaHa&mediaurl=https://registry.npmmirror.com/@lobehub/icons-static-png/latest/files/dark/gemini-color.png&q=gemini+logo&ck=238DA91F1CC55FFFFA2543D92B193614&idpp=rc&expw=1024&exph=1024&form=rc2idp&ajaxhist=0&ajaxserp=0" width="60"/><br><b>Gemini</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/x.svg" width="60"/><br><b>Grok</b>
# </td>
# </tr>
#
# <!-- Design & Media -->
# <tr>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=figma" width="60"/><br><b>Figma</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/canva.svg" width="60"/><br><b>Canva</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/obsstudio.svg" width="60"/><br><b>OBS Studio</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/capcut.svg" width="60"/><br><b>CapCut</b>
# </td>
# </tr>
#
# <!-- Communication -->
# <tr>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/anydesk.svg" width="60"/><br><b>AnyDesk</b>
# </td>
# <td align="center" width="150">
# <img src="https://skillicons.dev/icons?i=discord" width="60"/><br><b>Discord</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/microsoftedge.svg" width="60"/><br><b>Edge</b>
# </td>
# <td align="center" width="150">
# <img src="https://raw.githubusercontent.com/simple-icons/simple-icons/develop/icons/googlechrome.svg" width="60"/><br><b>Chrome</b>
# </td>
# </tr>
#
# </table>
