# %% [markdown]
# # Input and Basic Operation

# %% [markdown]
# ### Taking user input
#
#     In python we use that built-in function input(), function to get data from user through consol.
#         1. the input function pause the program and waits for the users to type somthing
#         2. it always turns the input as a string, regardless of what the users type

# %%
#input()

# %%
print("name")
# Out:
# name

# %%
print("hello World")
# Out:
# hello World

# %%
# name = input("Enter your name :")
name = "Naim"
print(name)
# Out:
# Naim

# %%
# age = input("enter your age : ")
age  = 21
print("your age is = ", age)
# Out:
# your age is =  21

# %%
type(age)
# Out:
# int

# %% [markdown]
# age = int(input())
#
# age = variable name
#
# int =  datatype
#
# input = input function

# %%
# age = int(input("Enter your age : "))
print("Your age is : ",age)

# %%
# salary = float(input("Enter your salary : "))
salary = 50
print("Your salary is : ",salary)
# Out:
# Your salary is :  50

# %% [markdown]
# ### Arethmatics Operator
#     1.      +   --> Addition    =   5 + 3    = 8
#     2.      -   --> Substraction    =   5 - 3   = 2
#     3.      *   --> Multiplication  =   5 * 3 = 15
#     4.      /   --> division    =   6 / 3 = 2
#     5.      //  --> floor division   = 8 // 3 = 2
#     6.      %   --> Modulas or Reminder = 5 % 2 =1
#     7.      **  --> Exponential = 2 ** 3 = 8

# %%
# A = int(input("Number A:" ))
# B = int(input("Number B: "))
A = 4
B = 3

# %% [markdown]
# ### Addition

# %%
sum = A + B
print("the sum = ", sum)
# Out:
# the sum =  7

# %% [markdown]
# ### Substruction

# %%
A = 20
B = 10
sub = A - B
print("The substruction is = ",sub)
# Out:
# The substruction is =  10

# %% [markdown]
# ### Multiplication

# %%
mul = A*B
print("the multilication is = ",mul)
# Out:
# the multilication is =  200

# %% [markdown]
# ### Division

# %%
div = A / B
print("division is = ", div)
# Out:
# division is =  2.0

# %% [markdown]
# ### floor division

# %%
a = 45
b = 10
f_div = a // b
print("floor division is = ", f_div)
# Out:
# floor division is =  4

# %% [markdown]
# ### Reminder

# %%
rem = a % b
print("reminder is = ",rem)
# Out:
# reminder is =  5

# %% [markdown]
# ### Exponential

# %%
x = 2
y = 4

exp = x ** 4

print("the exponential = ",exp)
# Out:
# the exponential =  16
