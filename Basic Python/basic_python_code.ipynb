# %% [markdown]
# # First code
# First python code

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %%
# print is a function that produce a output and show a display. 
# and we write ("---------somthing here")   --> it show a display output....

print("Hi, I'm Naim. weclome to python code.")
# Out:
# Hi, I'm Naim. weclome to python code.

# %%
# using doubble caotation
print("python"," is"," fun")
# Out:
# python  is  fun

# %%
# using single cotation
print('python', 'is', 'fun')
# Out:
# python is fun

# %% [markdown]
# ### separation

# %%
print("hello", "world","hi","I'm","Naim" , sep = '_')
# Out:
# hello_world_hi_I'm_Naim

# %% [markdown]
# Comment
#
# ### --> single line comment
#
# '''Multiline comment'''

# %%
# this is single line comment
print("# this is single line comment")
print("symbol  --> # somthing write but no prin")
# Out:
# # this is single line comment

# %%
'''this is multiline comment.'''
print("'''this is multiline comment'''")
print("Symbol  --> '''---somthing write but no print'''")
# Out:
# '''this is multiline comment'''
# Symbol  --> '''---somthing write ut no print'''

# %% [markdown]
# # Variable
#
# variable is a name that store a valu...

# %%
# for example
name = "Naim"  # string propertis
print("Namr is : ",name)


# Integer
age = 21  # that store Integer vlue
print("Age is : ",age)


# Float
hight = 5.9
print("Hight is : ",hight)
# Out:
# Namr is :  Naim
# Age is :  21
# Hight is :  5.9

# %% [markdown]
# ### Rules of varivale
#
# 1.  must start latter or Underscore And using cammel case or snack case BUT No space
#
#     --> varb name ❌
#     -->  varivale_name✅
#
#     -->  _var_name ✅
#
#     -->  VarName ✅
#
#     -->  Var_Name ✅
#
#     -->  is_name ✅
#
# 2. cannot start number or anything
#     example:
#     1_variable name ❌
#
#     --> But using snack case
#     var_1 ✅
#     var_2 ✅
#
# 3. case sensetive
#     example :    Age != age
#     both are deffrent
#
#
# 4.  should not use python keyword

# %% [markdown]
# ## Data Type
#
#
# --> Integer
#
# --> Float
#
# --> double
#
# --> String
#
#
# #### Example...
#
# 1.  name = "Naim"
#     here name is a variabele that store String propertis name Naim
#
#
# 2.  age = 21
#     here age is a variable that store integer value 21.
#
#
# 3.  same here other propertis....

# %%
name = "NAIM"
age = 21
hight = 5.9
is_student = True


print("String -->  Name : ",name)

print("Intrger --> Age : ", age)

print("Float --> Hight : ", hight)

print("Boolean --> Is_Student : ", is_student)
# Out:
# String -->  Name :  NAIM
# Intrger --> Age :  21
# Float --> Hight :  5.9
# Boolean --> Is_Student :  True

# %% [markdown]
# ## Type casting
#
# typecasting to change a value one type to another type

# %%
hight = 5.9

hight = int (hight)
print("Hight is Intger value : ",hight)
# Out:
# Hight is Intger value :  5

# %%
taka = 60.70
taka = int (taka)

print("integer value is : ", taka)

taka = float (taka)
print("Float value is : ",taka)
# Out:
# integer value is :  60
# Float value is :  60.0

# %% [markdown]
# #### find Data Type

# %%
name = "NAIM"
age = 21
hight = 5.9
is_student = True


print(type(name))
print(type(age))
print(type(hight))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
